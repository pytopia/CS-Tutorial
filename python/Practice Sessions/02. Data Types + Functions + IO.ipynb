# %% [markdown]
# # 02. Practice Session
#
# > Covering Data Types, Functions, and IO.

# %% [markdown]
# ## Search Engine (TF-IDF)
#
# > **TF-IDF** stands for “Term Frequency — Inverse Document Frequency”. This is a technique to quantify a word in documents, we generally compute a weight to each word which signifies the importance of the word in the document and corpus.
#
# If i give you a sentence for example _“This building is so tall”_. Its easy for us to understand the sentence as we know the semantics of the words and the sentence. But how will the computer understand this sentence? The computer can understand any data only in the form of numerical value. So, for this reason we vectorize all of the text so that the computer can understand the text better.

# %% [markdown]
# By vectorizing the documents we can further perform multiple tasks such as finding the relevant documents, ranking, clustering and so on. This is the same thing that happens when you perform a google search. The web pages are called documents and the search text with which you search is called a query. google maintains a fixed representation for all of the documents. When you search with a query, google will find the relevance of the query with all of the documents, ranks them in the order of relevance and shows you the top k documents, all of this process is done using the vectorized form of query and documents. Although Googles algorithms are highly sophisticated and optimized, this is their underlying structure.

# %% [markdown]
# Terminology
# - **t**: term (word)
# - **d**: document (set of words)
# - **N**: count of corpus
# - **corpus**: the total document set

# %% [markdown]
# ### Step #1: Read Files
#
# > 1. Read the `data/files_path.txt` which contains all the documents you have to read.
# > 2. Read the files listed in `data/files_path.txt` and create a dictionary where keys are file names and values are file contents.
#
# ```python
# docs = {
#     "file_1": "content_1",
#     "file_2": "content_2",
#     ...
# }
# ```

# %%
docs = {}

# %%
with open("./data/docs/docs.txt") as f:
    files = [f.strip() for f in f.readlines()]

# %%
for file_path in files:
    with open(file_path) as f:
        name = file_path.split("/")[-1].split(".")[0]
        if name in docs:
            docs[name] += f.read()
        else:
            docs[name] = f.read()

# %% [markdown]
# ### Step #3: Extract Unique Words in all Documents
#
# > Create a set of all words (`vocab`) and print the number of unique words.

# %%
vocab = set()
for name, content in docs.items():
    vocab.update(content.split())

# %%
print(len(vocab))
# Out:
# 9004

# %% [markdown]
# ### Step #2: Extract Number of Words in each Document
#
# > 1. Extract words in each document by creating a dictionary named `tf_dict` where keys are document names and values are another dictionary.
# > 2. In the nested dictionary, keys are words and values are the corresponding word frequency.

# %%
tf_dict = {}
for name, content in docs.items():
    
    word_dict = {}
    for w in content.split():
        if w in word_dict:
            word_dict[w] += 1
        else:
            word_dict[w] = 1
            
    tf_dict[name] = word_dict

# %% [markdown]
# ### Step #3: Create `tf` (Term Frequency)
#
# > 1. Create a dictionary where words are keys and values are a list.
# > 2. Values are a list of corresponding documents frequencies.
#
# ```python
# tf = {
#     word_1: [freq_doc_1, freq_doc_2, freq_doc_3, ..., freq_doc_n],
#     word_2: [freq_doc_1, freq_doc_2, freq_doc_3, ..., freq_doc_n],
#     word_3: [freq_doc_1, freq_doc_2, freq_doc_3, ..., freq_doc_n],
#     ...
#     word_n: [freq_doc_1, freq_doc_2, freq_doc_3, ..., freq_doc_n],
# }
# ```
#
# | |doc_1|doc_2|...|doc_n|
# |--|--|--|--|--|
# |word_1|10|4|...|14|
# |word_2|8|11|...|4|
# |word_3|3|5|...|1|

# %%
from tqdm import tqdm

# %%
tf = {}

# %%
for w in tqdm(vocab):
    vector = []
    for name, word_freq in tf_dict.items():
        vector.append(word_freq.get(w, 0))
        
    tf[w] = vector
# Out:
# 100%|██████████| 9004/9004 [00:00<00:00, 119980.79it/s]

# %%
max(tf["محسن"])
# Out:
# 149

# %%
tf.keys()
# Out:
# dict_keys(['محسن،', 'طرفی', 'قلق', 'درم', 'Mamnoon', 'بیفزایید.', 'شرمنده', 'توضیحات', 'کنجکاوی', 'که\u200cمافیا\u200cبازی\u200cمیکنن', '۱۱-پردیس', 'آموزش', 'پولاش', 'motmaen', 'julienne', 'بهتون', 'سابسرکیپشن', 'ببينم😋', 'نفس', 'اقایون\u200cخانوما،', 'ربع', 'نميكنم', 'ایشالله', 'اینهمه', 'واگرنه', 'كرده', 'سرعتی', 'کاسکو،', 'بیای...', 'اجازه', 'لرنینگ', 'حرفه', 'یور!', 'ناهار', 'كورلئونه:', 'ساعت.', 'نشاط', 'کنم!', 'زم', 'bekhoonim', 'راهمون', 'اونم', '☺️', 'مقدارش', 'فامیلامون', 'غبار', 'مزَگ', 'ياد', 'خوان', 'سريعتر', 'پایان', 'آخرین', 'miaratesh', 'کجا', 'دون-جادو-ترور-مذاکره', 'گیری', '14-مهسا', 'دوستان🌺🌺🌺', 'چسبید،', 'اسکولز', 'عكسايي.', 'لیلا', 'تخمه', 'نه', 'مطبخ', 'کنم\u200c', 'ببری', 'کن!', 'کنین..', 'محسوب', 'نذاشتین؟', 'کنن', 'مين', 'بوده؟', 'درسته', 'خلالي', 'نکنین.', 'esteghlali', 'بازنشستگی', 'Y&Y', 'اینم', 'سلام.', 'میخوابیدم', 'خاطره', 'ماهی', 'چيزي', 'خریم', 'رام', 'میاییم', 'غذا-دوباره', 'گرفتین', 'ببينيم', 'اینارا', 'كار', 'عربستان؟!', 'احتمالش', '10', 'غذایی', 'فر', 'بگیره.', 'باشیم،', 'خبرنگار،', 'هستند.', 'بهمون', 'نفری', 'آرتا', 'نفرمايين🙃', 'نقشها', 'کلاه\u200cقرمزی', 'شو', 'علي', 'قسمتهای', 'وسط', 'استقبال', 'عکسها', 'تفنگش', 'تمركز', 'mikonin?', 'روسیه؟', 'مشکلش', 'نو😊ایول،', 'نوش', '😅', 'meghdaare', 'مدل', 'زودتر', 'خوردم.', 'می\u200cکنه؟', 'nemikonim😂', 'کارها،', 'محتوای', 'تکمیلیم', 'انرژی', 'بيصبرانه', 'عزيزم❤️', '۳-لیلا', 'می\u200cدونم', 'شویی', 'حرص', 'دیدم،', 'برام', '😇', 'انتخاب', 'پاشی', 'براتون', 'اصلش', 'رو👌🏻😍', 'کنارتون', 'پايه', 'بازی.', '3.', 'میشدم', 'وایسین', 'ميلاد', 'Besaz', 'اندی', 'gereft', '👏🏻👏🏻👏🏻👏🏻❤️❤️❤️❤️', 'بگه', 'نگفت', 'كلگري', 'بياين', 'منطقه', 'farda', 'زینب', 'کنید!', 'خوره', 'ج', 'ئه', 'دل.', 'آره،', 'گوساله', 'پیشش.', 'انگلیس', '😂😏', '۱۰-سارا', 'میرسه)', '۱۲-سارا', 'بیف', 'خرد', '👍', 'ostad', 'آمادست.', 'Feiz.txt', 'واقعا.', 'چه', 'ادمونتون،', 'آمدن،', 'میدل', '🙏👍🏼', 'تونه', 'بودین', 'شناسنامه', 'مردش', 'Sibzaminie', 'برق', 'چقدر؟', 'کنیم؟', 'انتاریو', 'مافیا:', 'تنه', 'ميكنه', 'نمیان؟', 'دادنه!!!', 'گردی', 'رطب', 'داره🤣', 'گروه', 'ورزشکاه', 'بود\u200c\u200c', 'نپزیم', 'بازیه', 'فرستادم', '۱۴؟', '🙏🙏🙏', 'روشنتر', 'ره؟', 'غرب', '۹-', '8-', 'match', 'فیلمساز،', 'قاره', 'پول', '🕵\u200d♂️🕵\u200d♀️', 'کوبیده', 'ممنون\u200cایسان', 'بفرستیم', 'مثلا', 'بعد🙈؟', 'درنگ', 'تعارفا', 'محدودی', 'بانوان', 'افت', 'man', 'کنی', 'توضيح', 'بعد:', 'الان', 'كاري', 'میذاشت', 'هست»', 'spanning', 'ماشالا', 'کنسل.', 'دخترونه', 'تلفن', 'میارین🤣🤣', 'تمومن.', '👌😆', 'نبود؟؟', '۲۰', 'خدمتتون', 'ریموو', '"بابا', '🇮🇷چهارشنبه', 'اینکارتو❤️❤️', 'نمیرسه', 'همدیگه.', 'خواستیم', '😘😘😘', 'همراهم', 'میومدیم', ':۶', 'زوووم', 'قرمه', 'مغز', 'نیمه', '🚶\u200d♂️🚶\u200d♂️🚶\u200d♂️🚶\u200d♂️🚶\u200d♂️', 'موج', 'همکاری', 'ذکره', 'گویا', 'حدودا', 'احسنت!', 'می\u200cکنی.', 'پتانسیل', '😂😂😂😂😂😂', 'کلگری', 'بذار', '۱۴-مهیار', 'يكم', 'چیزها', 'نه😉', 'عرض', '\U0001f977', 'مافیاخثها', 'تنكس', '(۷:۳۰', 'ليستو', 'Amir', 'قبل،', 'احتمالن', 'اول)', 'می\u200cایستم', 'شهره', 'براي', 'مافیا؟!', 'پزشک-تک', 'باقیمانده', 'بررسی', 'Karami.txt', 'میبره', 'واويلا', 'نمیدیم،', 'دلم\u200c', 'ابراز', 'لپه', 'پرش', 'بر', 'قنبری،', '۱۰.', 'سارا.', 'تقصیر', 'هرکس', '١٨-', 'زدین', '🤩', 'خویش', 'زن!', 'میکردم', 'لینکم', 'ویکند', 'دیدن', 'نیستن.', 'ندارم،', 'اا', 'شده', 'مهمون', 'هنوزم', 'قفلی', 'داشتم', 'قد.', 'اونقدر', 'بخوایم', 'بالاوي', 'میناوند', 'ميشم', 'دوغ', 'بجاش؟', '«همسایه', 'خبرنگار', 'dashtamo', 'مافیا؟', 'اينجوري', 'مجازات', 'سقیل', '۸:۱۵.', 'حرفی', 'چیکار', 'میوفتادم', '🙏🏻🙏🏻🙏🏻🙏🏻', 'بدل', 'پوزه', 'ه', 'شدين؟', 'ادمونتون:', 'مسدود', 'غضنفري', 'می\u200cپیچونن', 'سرکار', 'پینش', 'کوچولوی', 'سیر', 'روبه', 'که', 'اجازه\u200cی', 'خوانی', 'جمعه.', 'علیرام؟', 'مرسی.', 'نادرسته.', 'نیازمندیم', '😭😭😭😭😭', 'رفت.', 'اصولی', 'پیشینه\u200cی', 'بوده😜', 'چیه؟', 'كليپ', 'بفرس', 'ندیم😂', 'حل', 'نزدم', 'پذیرفته', 'امین!', '😰😰😰😰', 'نمیزد', 'بالک\u200cبارن', 'ماکارونی', '«محسن', 'تونیم', 'enough', 'اکیه', 'باهاتون', 'نقشهای', 'took', 'baaz', 'صفی', 'كرد😅', 'ها', 'خودم\u200cکوچکترین', 'بندیه.', 'لعاب،', 'سرکارم', 'وارده', 'رشته', 'تاشون', 'بعدي🙂', '😂👍🏼', 'نجفي، ...
